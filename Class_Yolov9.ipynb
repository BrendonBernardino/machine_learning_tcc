# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendonBernardino/machine_learning_tcc/blob/master/Class_Yolov9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Wed Feb 26 02:21:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
cd /content/drive/MyDrive/Dataset_TCC/yolo_process/
# Out:
# /content/drive/MyDrive/Dataset_TCC/yolo_process

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Total 325 (delta 0), reused 0 (delta 0), pack-reused 325 (from 1)
# Receiving objects: 100% (325/325), 2.25 MiB | 2.43 MiB/s, done.
# Resolving deltas: 100% (162/162), done.

# %%
cd yolov9
# Out:
# /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9

# %%
# !pip install -r requirements.txt -q

# %%
cd ..
# Out:
# /content/drive/MyDrive/Dataset_TCC/yolo_process

# %%
# !wget -P /content/drive/MyDrive/Dataset_TCC/yolo_process/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-m.pt

# %%
# !wget -P /content/drive/MyDrive/Dataset_TCC/yolo_process/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt

# %%
cd yolov9
# Out:
# /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9

# %%
# !python train_dual.py \
--workers 8 --batch 16 --epochs 100 --img 240 --device 0 --patience 15\
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/weights/yolov9-m.pt \
--cfg /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/models/detect/yolov9_custom.yaml
# --hyp /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# 2025-02-22 19:20:15.318282: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740252015.339120   11042 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740252015.345331   11042 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-22 19:20:15.366809: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python detect.py \
--img 240 --conf-thres 0.45 --device 0 \
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp3/weights/best.pt \
--source /content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/test/images \
--project /content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/output \
--name images
# Out:
# detect: weights=['/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/test/images, data=/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml, imgsz=[240, 240], conf_thres=0.45, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/output, name=images, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# ...

# %%
# !python detect.py \
--img 240 --conf-thres 0.45 --iou-thres 0.1 --device 0 \
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp3/weights/best.pt \
--source /content/drive/MyDrive/Dataset_TCC/ESP_Slave \
--project /content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/output \
--name images_espcam2
# Out:
# detect: weights=['/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Dataset_TCC/ESP_Slave, data=/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml, imgsz=[240, 240], conf_thres=0.45, iou_thres=0.1, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/output, name=images_espcam2, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# ...

# %%
# !python detect.py \
--img 240 --conf-thres 0.55 --iou-thres 0.1 --device 0 \
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp3/weights/best.pt \
--source /content/drive/MyDrive/Dataset_TCC/ESP_Slave \
--project /content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/output \
--name images_espcam2_teste2
# Out:
# detect: weights=['/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Dataset_TCC/ESP_Slave, data=/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml, imgsz=[240, 240], conf_thres=0.55, iou_thres=0.1, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_240.yolov9/output, name=images_espcam2_teste2, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# ...

# %% [markdown]
# # **Treinamento com as classes: vazio, meiovazio, meiocheio, cheio, utilizando modelo Yolov9-M**

# %%
# !python train_dual.py \
--workers 8 --batch 16 --epochs 100 --img 288 --device 0 --patience 15\
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/weights/yolov9-m.pt \
--cfg /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/models/detect/yolov9_custom.yaml
# --hyp /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# 2025-02-23 00:17:24.364477: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740269844.628906   10172 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740269844.694896   10172 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-23 00:17:25.219766: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python detect.py \
--img 288 --conf-thres 0.55 --iou-thres 0.1 --device 0 \
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp4/weights/best.pt \
--source /content/drive/MyDrive/Dataset_TCC/ESP_Slave \
--project /content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_288.yolov9/output \
--name images_espcam2_teste_288
# Out:
# detect: weights=['/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp4/weights/best.pt'], source=/content/drive/MyDrive/Dataset_TCC/ESP_Slave, data=/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml, imgsz=[288, 288], conf_thres=0.55, iou_thres=0.1, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/Dataset_TCC/yolo_process/Cocho_288.yolov9/output, name=images_espcam2_teste_288, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# ...

# %% [markdown]
# # **Treinamento com as classes: cow, occluded_trough, empty_trough, partial_trough, full_trough, utilizando modelo Yolov9-M**

# %%
# !python train_dual.py \
--workers 8 --batch 16 --epochs 100 --img 288 --device 0 --patience 20\
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/weights/yolov9-m.pt \
--cfg /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/models/detect/yolov9_custom.yaml
# --hyp /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# 2025-02-26 02:21:25.859366: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740536485.880034   12394 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740536485.886262   12394 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-26 02:21:25.908441: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # **Treinamento com as classes: cow, occluded_trough, empty_trough, partial_trough, full_trough, utilizando modelo Yolov9-E**

# %%
# !python train_dual.py \
--workers 8 --batch 16 --epochs 100 --img 288 --device 0 --patience 20\
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/weights/yolov9-e.pt \
--cfg /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/models/detect/yolov9_custom.yaml
# Out:
# 2025-02-26 03:15:45.142903: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740539745.165433   26393 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740539745.171800   26393 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-26 03:15:45.192970: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python detect.py \
--img 288 --conf-thres 0.45 --device 0 \
--data /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml \
--weights /content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp8/weights/best.pt \
--source /content/drive/MyDrive/Dataset_TCC/ESP_Slave \
--project /content/drive/MyDrive/Dataset_TCC/yolo_process/classification_trough_count_cow.yolov9/output \
--name images_espcam2_teste_
# Out:
# detect: weights=['/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/runs/train/exp8/weights/best.pt'], source=/content/drive/MyDrive/Dataset_TCC/ESP_Slave, data=/content/drive/MyDrive/Dataset_TCC/yolo_process/yolov9/data.yaml, imgsz=[288, 288], conf_thres=0.45, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/Dataset_TCC/yolo_process/classification_trough_count_cow.yolov9/output, name=images_espcam2_teste_, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# ...
